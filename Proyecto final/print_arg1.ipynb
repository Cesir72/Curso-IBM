# %%
def dummy():
    i=2
    print(i)
    i+=1
dummy()
# Out:
# 2

# %%
def ha():
    print('Ha')
    return 'Ha'
ha()
# Out:
# Ha
# 'Ha'

# %%
def bar(x):
    y = input()
    print(y)
    print(x)
bar(5)
# Out:
# 10
# 10
# 5

# %%
def f2():
    global y
    x, y = 5, 6
    print([x, y])
f2()
# Out:
# [5, 6]
